# %% [markdown]
# # Hardware Trojan Insertion Lab
#
# This notebook demonstrates practical hardware Trojan insertion using the GHOST system with AI models.
#
# ## Objective
# - Generate hardware Trojans using AI-powered insertion techniques
# - Test different vulnerability types on various hardware designs
# - Analyze and validate generated Trojaned designs
# - Build datasets for security research
#
# ## Prerequisites
# - Valid API key (OpenAI, Anthropic, Google, or TogetherAI)
# - Basic understanding of Verilog RTL design
# - Familiarity with hardware security concepts

# %% [markdown]
# ## 🦠 **TROJAN INSERTION SYSTEM**
#
# This section demonstrates hardware Trojan insertion using AI models:
# - **Direct Trojan generation** for RTL designs
# - **Multiple vulnerability types** (T1-T4) with different attack vectors
# - **Batch processing** capabilities for multiple designs
# - **Analysis and validation** of generated Trojaned hardware

# %%
# !pip install openai
# !pip install anthropic
# !pip install together
# !pip install google-genai
# Out:
# Requirement already satisfied: openai in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (2.33.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (2.13.3)
# Requirement already satisfied: sniffio in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: anthropic in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (0.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: together in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (2.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (4.13.0)
# Requirement already satisfied: cyclopts>=4.6.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (4.11.2)
# Requirement already satisfied: detect-agent>=0.2.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (0.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (1.9.0)
# Requirement already satisfied: filelock>=3.13.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (3.29.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (0.28.1)
# Requirement already satisfied: pillow>=10.4.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (12.2.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (2.13.3)
# Requirement already satisfied: rich>=13.7.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (15.0.0)
# Requirement already satisfied: sniffio in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (1.3.1)
# Requirement already satisfied: tabulate>=0.9.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (0.10.0)
# Requirement already satisfied: tqdm>=4.67.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (4.67.3)
# Requirement already satisfied: types-pyyaml>=6.0.12.20250915 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (6.0.12.20260408)
# Requirement already satisfied: types-tabulate>=0.9.0.20240106 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (0.10.0.20260408)
# Requirement already satisfied: types-tqdm>=4.67.0.20250516 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (4.67.3.20260408)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from together) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->together) (3.13)
# Requirement already satisfied: certifi in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->together) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->together) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->together) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->together) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->together) (0.4.2)
# Requirement already satisfied: attrs>=23.1.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from cyclopts>=4.6.0->together) (26.1.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from cyclopts>=4.6.0->together) (0.18.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from cyclopts>=4.6.0->together) (1.3.2)
# Requirement already satisfied: docutils in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.6.0->together) (0.22.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from rich>=13.7.1->together) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from rich>=13.7.1->together) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->together) (0.1.2)
# Requirement already satisfied: types-requests in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from types-tqdm>=4.67.0.20250516->together) (2.33.0.20260503)
# Requirement already satisfied: urllib3>=2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from types-requests->types-tqdm>=4.67.0.20250516->together) (2.6.3)
# Requirement already satisfied: google-genai in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (1.74.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.50.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (2.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.13)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (47.0.0)
# Requirement already satisfied: certifi in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/eiliscasey/Documents/Spring 2026/Hardware Security/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)

# %%
#@title Setup: Import GHOST System for Trojan Insertion
import sys
import os
sys.path.append('.')

# Import the GHOST Trojan insertion system
import GHOST_Trojan_GPT as ghost

print("🦠 GHOST Hardware Trojan Insertion System")
print("="*50)

# Display available vulnerability types
print("Available Vulnerability Types:")
for vid, desc in ghost.vulnerabilities.items():
    print(f"  {vid}: {desc}")

print("\nAvailable Prompting Strategies:")
for vid, strategy in ghost.prompting_strategies.items():
    print(f"  {vid}: {strategy}")

print("\n✅ GHOST system imported successfully")
print("💡 Next step: Configure API backend and model")
# Out:
# 🦠 GHOST Hardware Trojan Insertion System
# ==================================================
# Available Vulnerability Types:
#   T1: functional-modification vulnerability
#   T2: information-leakage vulnerability
#   T3: availability-degradation vulnerability
#   T4: performance-degradation vulnerability
#
# Available Prompting Strategies:
#   T1: Add a rare-trigger conditional path that causes subtly incorrect output under a specific input pattern, for use as a detection benchmark.
#   T2: Add a signal-observation path that makes internal state visible on an output wire under a specific trigger condition, annotated for security analysis.
#   T3: Add a rare-condition stall mechanism that temporarily halts the module, annotated as a detection target for formal verification tools.
#   T4: Add a continuously active register that increases switching activity without affecting primary outputs, annotated as a power-analysis detection benchmark.
#
# ✅ GHOST system imported successfully
# 💡 Next step: Configure API backend and model

# %%
import os
# Load API key from environment (set via .env file or shell export)
# Never hardcode secrets here — use: set -a; source .env; set +a
if not os.getenv("OPENAI_API_KEY"):
    print("⚠️  OPENAI_API_KEY not set — live generation cells will be skipped.")
    print("   Analysis tasks (3, 4, 5) run fine without it.")
else:
    print("✅ OPENAI_API_KEY found.")
# Out:
# ⚠️  OPENAI_API_KEY not set — live generation cells will be skipped.
#    Analysis tasks (3, 4, 5) run fine without it.

# %%
#@title 11. Setup GHOST System for Real API Calls
# Import the GHOST system
import sys
sys.path.append('.')
from GHOST_Trojan_GPT import setup, construct_prompt, model_inference, extract_code_and_metadata
from GHOST_Trojan_GPT import vulnerabilities, prompting_strategies

# Setup the backend - requires API key to be set in environment
try:
    setup("OpenAI")  # Change to "Anthropic", "Google", or "TogetherAI" as needed
    print("✅ GHOST system initialized successfully")
    print("🔑 API connection established")
except Exception as e:
    print(f"❌ Setup failed: {e}")
    print("💡 Make sure your API key is set in the environment")
    print("   For OpenAI: export OPENAI_API_KEY=your_key_here")
# Out:
# ❌ Setup failed: OPENAI_API_KEY environment variable not set
# 💡 Make sure your API key is set in the environment
#    For OpenAI: export OPENAI_API_KEY=your_key_here

# %%
#@title 12. Demonstrate Trojan Insertion on Sample Verilog
# Define a sample clean Verilog design for demonstration
sample_design = '''
module simple_counter(
    input wire clk,
    input wire rst,
    input wire enable,
    output reg [7:0] count
);

always @(posedge clk or posedge rst) begin
    if (rst) begin
        count <= 8'b0;
    end else if (enable) begin
        count <= count + 1;
    end
end

endmodule
'''

print("🎯 Original Clean Design:")
print("="*60)
print(sample_design)
print("="*60)

# Select vulnerability type and strategy
vulnerability_type = "T1"  # Change functionality
vulnerability_desc = vulnerabilities[vulnerability_type]
strategy = prompting_strategies[vulnerability_type]

print(f"\n🎯 Target Vulnerability: {vulnerability_type} - {vulnerability_desc}")
print(f"📋 Strategy: {strategy}")
print("\n" + "="*60)
# Out:
# 🎯 Original Clean Design:
# ============================================================
#
# module simple_counter(
#     input wire clk,
#     input wire rst,
#     input wire enable,
#     output reg [7:0] count
# );
#
# always @(posedge clk or posedge rst) begin
#     if (rst) begin
#         count <= 8'b0;
#     end else if (enable) begin
#         count <= count + 1;
#     end
# end
#
# endmodule
#
# ============================================================
#
# 🎯 Target Vulnerability: T1 - functional-modification vulnerability
# 📋 Strategy: Add a rare-trigger conditional path that causes subtly incorrect output under a specific input pattern, for use as a detection benchmark.
#
# ============================================================

# %%
#@title 13. Execute Trojan Insertion via API Call
import GHOST_Trojan_GPT as ghost

# Set the model (update this to your preferred model)
ghost.model = "gpt-4.1"  # or "gpt-4o", "claude-3-5-sonnet-20241022", etc.

print("🚀 Generating Trojan insertion prompt...")
prompt = construct_prompt(sample_design, vulnerability_desc, strategy)
print("📝 Prompt constructed successfully")
print(prompt)

print("\n🔄 Calling AI model for Trojan insertion...")
print("⏳ This may take a few moments...")

try:
    # Make the actual API call
    response = model_inference(prompt)
    print("✅ AI model response received")

    # Extract structured components
    trojan_code, explanation, trigger, payload, taxonomy = extract_code_and_metadata(response)

    print("\n" + "="*80)
    print("🦠 TROJAN INSERTION RESULTS")
    print("="*80)

    print(f"\n📊 EXPLANATION:\n{explanation}\n")
    print(f"🎯 TRIGGER MECHANISM:\n{trigger}\n")
    print(f"💥 PAYLOAD EFFECTS:\n{payload}\n")
    print(f"🏷️  TAXONOMY:\n{taxonomy}\n")

    print("="*80)
    print("💻 TROJANED VERILOG CODE:")
    print("="*80)
    print(trojan_code)

except Exception as e:
    print(f"❌ Error during Trojan insertion: {e}")
    print("💡 Check your API key and internet connection")
# Out:
# 🚀 Generating Trojan insertion prompt...
# 📝 Prompt constructed successfully
#
# You are generating an annotated RTL security benchmark for academic hardware security research. The goal is to produce a Verilog example containing a known functional-modification vulnerability that detection tools can be evaluated against.
#
# Original design:
# <
# module simple_counter(
#     input wire clk,
#     input wire rst,
#     input wire enable,
#     output reg [7:0] count
# );
#
# always @(posedge clk or posedge rst) begin
#     if (rst) begin
#         count <= 8'b0;
#     end else if (enable) begin
#         count <= count + 1;
#     end
# end
#
# endmodule
# >
#
# Task: Produce a modified version of this design that demonstrates a functional-modification vulnerability. Strategy: Add a rare-trigger conditional path that causes subtly incorrect output under a specific input pattern, for use as a detection benchmark.
# The modification must preserve all original functionality except under the specific trigger condition. The result must be fully synthesizable and heavily annotated so researchers can identify the added vulnerability easily.
#
# Synthesizable Design Guidelines:
# 1. Implement proper reset logic and initialize all registers and state elements.
# 2. Use counters for time/event-based triggers.
# 3. Handle all cases in conditional logic, including else and default cases.
# 4. Omit non-synthesizable constructs (initial blocks, $display).
# 5. All modifications must use synthesizable Verilog constructs only.
#
# Respond using exactly this format (one instance of each section, no repetition):
#
# Code:
# <Complete modified Verilog with comments marking the added vulnerability region>
#
# Explanation:
# <Two-line description of how the vulnerability was added and its effect>
#
# Trigger:
# <Two-line description of the trigger condition and how it activates>
#
# Payload:
# <Two-line description of the payload behavior when triggered>
#
# Taxonomy:
# <Insertion phase: Design
# Abstraction level: Register-transfer level
# Activation mechanism: [Specify: Always-on, Triggered internally/externally, etc.]
# Effects: functional-modification vulnerability
# Location: [Specify: Processor, Memory, I/O, Power Supply, Clock Grid]
# Characteristics: [Specify: Distribution, Size, Type (Functional/Parametric)]>
#
# Each added vulnerability code block must be enclosed in // trojan_insertion_begin and // trojan_insertion_end comments.
#
#
# 🔄 Calling AI model for Trojan insertion...
# ⏳ This may take a few moments...
# ❌ Error during Trojan insertion: Client not initialized. Call setup() first.
# 💡 Check your API key and internet connection

# %%
#@title 14. Batch Processing Multiple Designs & Vulnerabilities
from GHOST_Trojan_GPT import main, load_base_designs
import os

# Create a temporary directory with sample designs for demonstration
temp_dir = "./demo_designs"
os.makedirs(temp_dir, exist_ok=True)

# Sample designs for batch testing
designs = {
    "alu_simple.v": '''
module alu_simple(
    input [7:0] a, b,
    input [2:0] op,
    output reg [7:0] result
);

always @(*) begin
    case(op)
        3'b000: result = a + b;
        3'b001: result = a - b;
        3'b010: result = a & b;
        3'b011: result = a | b;
        default: result = 8'b0;
    endcase
end
endmodule
''',
    "shift_reg.v": '''
module shift_reg(
    input clk, rst, shift_in,
    output reg [7:0] data_out
);

always @(posedge clk or posedge rst) begin
    if (rst)
        data_out <= 8'b0;
    else
        data_out <= {data_out[6:0], shift_in};
end
endmodule
'''
}

# Write designs to files
for filename, content in designs.items():
    with open(os.path.join(temp_dir, filename), 'w') as f:
        f.write(content.strip())

print(f"📁 Created {len(designs)} sample designs in {temp_dir}/")
print("📋 Available designs:")
for filename in designs.keys():
    print(f"   • {filename}")

print(f"\n🎯 Available vulnerabilities:")
for vid, desc in vulnerabilities.items():
    print(f"   • {vid}: {desc}")

print("\n⚙️  Ready for batch processing!")
print("🚨 WARNING: This will make actual API calls and generate Trojaned designs")
# Out:
# 📁 Created 2 sample designs in ./demo_designs/
# 📋 Available designs:
#    • alu_simple.v
#    • shift_reg.v
#
# 🎯 Available vulnerabilities:
#    • T1: functional-modification vulnerability
#    • T2: information-leakage vulnerability
#    • T3: availability-degradation vulnerability
#    • T4: performance-degradation vulnerability
#
# ⚙️  Ready for batch processing!
# 🚨 WARNING: This will make actual API calls and generate Trojaned designs

# %%
#@title 15. Execute Batch Trojan Generation (LIVE API CALLS)
# ⚠️ CAUTION: This cell makes real API calls and costs money!
# Set this to True only when you want to actually run the batch job
RUN_BATCH_JOB = False  # Keep False for submission — pre-built outputs are in batch_trojan_designs/

if RUN_BATCH_JOB:
    print("🚀 Starting batch Trojan insertion job...")
    print("💰 Note: This will consume API credits")

    # Run the main GHOST function
    main(
        version_number=1,
        design_file=None,  # Process all files in directory
        base_designs_directory=temp_dir,
        vulnerable_designs_directory="./trojan_outputs",
        vulnerability_ids=['T1', 'T2'],  # Only run subset for demo
        num_threads=2  # Use fewer threads for demo
    )

    print("\n✅ Batch job completed!")
    print("📁 Check ./trojan_outputs/ for generated Trojaned designs")

else:
    print("ℹ️  Batch job not executed (RUN_BATCH_JOB = False)")
    print("💡 Set RUN_BATCH_JOB = True in the cell above to run the actual batch job")
    print("⚠️  Remember: This will make real API calls and generate Trojaned designs")

    # Show what would be processed
    print(f"\n📋 Would process:")
    for filename in designs.keys():
        for vid in ['T1', 'T2']:
            print(f"   • {filename} + {vid} ({vulnerabilities[vid]})")

    print(f"\n💰 Estimated API calls: {len(designs) * 2}")
# Out:
# ℹ️  Batch job not executed (RUN_BATCH_JOB = False)
# 💡 Set RUN_BATCH_JOB = True in the cell above to run the actual batch job
# ⚠️  Remember: This will make real API calls and generate Trojaned designs
#
# 📋 Would process:
#    • alu_simple.v + T1 (functional-modification vulnerability)
#    • alu_simple.v + T2 (information-leakage vulnerability)
#    • shift_reg.v + T1 (functional-modification vulnerability)
#    • shift_reg.v + T2 (information-leakage vulnerability)
#
# 💰 Estimated API calls: 4

# %%
#@title 16. Analyze Generated Trojaned Designs
import os
import glob

def analyze_trojan_outputs(output_dir="./trojan_outputs"):
    """Analyze the structure and content of generated Trojaned designs"""

    if not os.path.exists(output_dir):
        print(f"🔍 No output directory found at {output_dir}")
        print("💡 Run the batch job first to generate Trojaned designs")
        return

    # Find all generated files
    verilog_files = glob.glob(f"{output_dir}/**/*.v", recursive=True)
    taxonomy_files = glob.glob(f"{output_dir}/**/*_taxonomy.txt", recursive=True)

    print(f"📊 TROJAN GENERATION ANALYSIS")
    print("="*60)
    print(f"📁 Output directory: {output_dir}")
    print(f"🔧 Verilog files generated: {len(verilog_files)}")
    print(f"📋 Taxonomy files generated: {len(taxonomy_files)}")

    if verilog_files:
        print(f"\n💻 Generated Trojan Designs:")
        for vfile in verilog_files[:5]:  # Show first 5
            rel_path = os.path.relpath(vfile)
            size = os.path.getsize(vfile)
            print(f"   • {rel_path} ({size} bytes)")

        if len(verilog_files) > 5:
            print(f"   ... and {len(verilog_files) - 5} more")

        # Show sample Trojaned design
        print(f"\n🔍 Sample Trojaned Design Content:")
        print("-"*60)
        with open(verilog_files[0], 'r') as f:
            content = f.read()
            print(content[:1000], "..." if len(content) > 1000 else "")

        # Show corresponding taxonomy
        base_name = os.path.splitext(os.path.basename(verilog_files[0]))[0]
        taxonomy_file = next((f for f in taxonomy_files if base_name in f), None)

        if taxonomy_file:
            print(f"\n📋 Corresponding Taxonomy:")
            print("-"*60)
            with open(taxonomy_file, 'r') as f:
                print(f.read())
    else:
        print("\n❌ No Trojan designs found - run the batch job first")

# Run the analysis
analyze_trojan_outputs()
# Out:
# 🔍 No output directory found at ./trojan_outputs
# 💡 Run the batch job first to generate Trojaned designs

# %% [markdown]
# ## 🎯 **TROJAN INSERTION TASKS**
#
# Complete the following tasks to demonstrate Trojan insertion capabilities:

# %% [markdown]
# ### **Task 1: Single Trojan Insertion**
# Insert a specific Trojan type into a target design and analyze the results.

# %%
#@title Task 1: Single Trojan Insertion
import GHOST_Trojan_GPT as ghost

# Target design for Trojan insertion
target_cpu = '''
module simple_cpu(
    input clk, rst,
    input [31:0] instruction,
    input [31:0] data_in,
    output reg [31:0] data_out,
    output reg [31:0] pc,
    output reg mem_write
);
    reg [31:0] registers [0:7];
    wire [2:0] opcode = instruction[31:29];
    wire [2:0] rd = instruction[28:26];
    wire [2:0] rs1 = instruction[25:23];
    wire [2:0] rs2 = instruction[22:20];

    always @(posedge clk or posedge rst) begin
        if (rst) begin
            pc <= 32'h0;
            mem_write <= 1'b0;
            data_out <= 32'h0;
        end else begin
            case (opcode)
                3'b000: registers[rd] <= registers[rs1] + registers[rs2]; // ADD
                3'b001: registers[rd] <= registers[rs1] - registers[rs2]; // SUB
                3'b010: registers[rd] <= registers[rs1] & registers[rs2]; // AND
                3'b011: registers[rd] <= registers[rs1] | registers[rs2]; // OR
                3'b100: data_out <= registers[rs1]; mem_write <= 1'b1;   // STORE
                3'b101: registers[rd] <= data_in;                        // LOAD
                default: ; // NOP
            endcase
            pc <= pc + 4;
        end
    end
endmodule
'''

print("🦠 TASK 1: Single Trojan Insertion")
print("=" * 50)
print("🎯 Target: Simple CPU design")
print("🔴 Vulnerability: T1 (Change functionality)")
print("🤖 AI Model: Set ghost.model to your preferred model")
print("\n📋 Steps:")
print("1. Set up GHOST system (cell 11)")
print("2. Configure ghost.model = 'your-model'")
print("3. Run the insertion below")
print("4. Analyze the results")

print("\n💻 Original Design:")
print("-" * 30)
print(target_cpu[:400] + "\\n... (truncated)")

# Execute Trojan insertion for T1 (change functionality)
RUN_INSERTION = False  # Set to True to execute

if RUN_INSERTION:
    try:
        # Configure for T1 vulnerability
        vulnerability = ghost.vulnerabilities["T1"]
        strategy = ghost.prompting_strategies["T1"]

        print(f"\\n🚀 Inserting {vulnerability} Trojan...")
        prompt = ghost.construct_prompt(target_cpu, vulnerability, strategy)
        response = ghost.model_inference(prompt)

        # Extract results
        code, explanation, trigger, payload, taxonomy = ghost.extract_code_and_metadata(response)

        print("\\n" + "=" * 60)
        print("🦠 TROJAN INSERTION RESULTS")
        print("=" * 60)
        print(f"📝 Explanation: {explanation}")
        print(f"🎯 Trigger: {trigger}")
        print(f"💥 Payload: {payload}")
        print("\\n💻 Trojaned Code:")
        print("-" * 30)
        print(code[:800] + ("\\n... (truncated)" if len(code) > 800 else ""))

    except Exception as e:
        print(f"❌ Error: {e}")
else:
    print("\\n⚠️  Set RUN_INSERTION = True to execute")
    print("💡 Make sure to:")
    print("   • Run setup cell first")
    print("   • Set ghost.model = 'gpt-4' (or preferred model)")
    print("   • Ensure API key is configured")
# Out:
# 🦠 TASK 1: Single Trojan Insertion
# ==================================================
# 🎯 Target: Simple CPU design
# 🔴 Vulnerability: T1 (Change functionality)
# 🤖 AI Model: Set ghost.model to your preferred model
#
# 📋 Steps:
# 1. Set up GHOST system (cell 11)
# 2. Configure ghost.model = 'your-model'
# 3. Run the insertion below
# 4. Analyze the results
#
# 💻 Original Design:
# ------------------------------
#
# module simple_cpu(
#     input clk, rst,
#     input [31:0] instruction,
#     input [31:0] data_in,
#     output reg [31:0] data_out,
#     output reg [31:0] pc,
#     output reg mem_write
# );
#     reg [31:0] registers [0:7];
#     wire [2:0] opcode = instruction[31:29];
#     wire [2:0] rd = instruction[28:26];
#     wire [2:0] rs1 = instruction[25:23];
#     wire [2:0] rs2 = instruction[22:20];
#
#     always @(posedg\n... (truncated)
# \n⚠️  Set RUN_INSERTION = True to execute
# 💡 Make sure to:
#    • Run setup cell first
#    • Set ghost.model = 'gpt-4' (or preferred model)
#    • Ensure API key is configured

# %% [markdown]
# ### **Task 2: Batch Trojan Generation**
# Generate multiple Trojans across different vulnerability types and designs.

# %%
#@title Task 2: Batch Trojan Generation
import os

# Create multiple target designs for batch processing
hw_designs = {
    "aes_sbox.v": '''
module aes_sbox(
    input [7:0] data_in,
    output reg [7:0] data_out
);
    always @(*) begin
        case(data_in)
            8'h00: data_out = 8'h63;
            8'h01: data_out = 8'h7C;
            8'h02: data_out = 8'h77;
            8'h03: data_out = 8'h7B;
            default: data_out = 8'h00;
        endcase
    end
endmodule''',

    "uart_controller.v": '''
module uart_controller(
    input clk, rst, tx_start,
    input [7:0] tx_data,
    output reg tx, tx_busy
);
    reg [3:0] bit_count;
    reg [7:0] shift_reg;

    always @(posedge clk or posedge rst) begin
        if (rst) begin
            tx <= 1'b1;
            tx_busy <= 1'b0;
            bit_count <= 4'h0;
        end else if (tx_start && !tx_busy) begin
            shift_reg <= tx_data;
            tx_busy <= 1'b1;
            tx <= 1'b0; // start bit
            bit_count <= 4'h0;
        end else if (tx_busy) begin
            if (bit_count < 8) begin
                tx <= shift_reg[0];
                shift_reg <= {1'b0, shift_reg[7:1]};
                bit_count <= bit_count + 1;
            end else begin
                tx <= 1'b1; // stop bit
                tx_busy <= 1'b0;
            end
        end
    end
endmodule'''
}

# Setup batch processing directory
batch_dir = "./batch_trojan_designs"
output_dir = "./trojaned_outputs"
os.makedirs(batch_dir, exist_ok=True)

# Write designs to files
for filename, content in hw_designs.items():
    with open(f"{batch_dir}/{filename}", 'w') as f:
        f.write(content)

print("🦠 TASK 2: Batch Trojan Generation")
print("=" * 50)
print(f"📁 Created {len(hw_designs)} baseline designs in {batch_dir}/")

print("\\n📋 Available Designs:")
for filename in hw_designs.keys():
    print(f"   • {filename}")

print("\\n🎯 Vulnerability Types to Generate:")
for vid, desc in ghost.vulnerabilities.items():
    print(f"   • {vid}: {desc}")

print("\\n💼 Batch Processing Options:")
print("Option A: All vulnerabilities on all designs")
print("Option B: Specific vulnerabilities only")
print("Option C: Single design, all vulnerabilities")

# Batch execution configuration
RUN_BATCH = False  # Set to True to execute
BATCH_OPTION = "A"  # A, B, or C
SELECTED_VULNS = ["T1", "T2"]  # Used for Option B
SELECTED_DESIGN = "aes_sbox.v"  # Used for Option C

if RUN_BATCH:
    print(f"\\n🚀 Starting Batch Option {BATCH_OPTION}...")

    if BATCH_OPTION == "A":
        # All vulnerabilities on all designs
        ghost.main(
            version_number=1,
            base_designs_directory=batch_dir,
            vulnerable_designs_directory=output_dir,
            vulnerability_ids=None,  # All vulnerabilities
            num_threads=2
        )
    elif BATCH_OPTION == "B":
        # Specific vulnerabilities only
        ghost.main(
            version_number=1,
            base_designs_directory=batch_dir,
            vulnerable_designs_directory=output_dir,
            vulnerability_ids=SELECTED_VULNS,
            num_threads=2
        )
    elif BATCH_OPTION == "C":
        # Single design, all vulnerabilities
        ghost.main(
            version_number=1,
            design_file=f"{batch_dir}/{SELECTED_DESIGN}",
            vulnerable_designs_directory=output_dir,
            vulnerability_ids=None,
            num_threads=2
        )

    print("\\n✅ Batch processing completed!")
    print(f"📁 Check {output_dir}/ for generated Trojaned designs")

else:
    print("\\n⚠️  Set RUN_BATCH = True to execute batch job")
    print("💡 Configuration:")
    print(f"   • Option: {BATCH_OPTION}")
    if BATCH_OPTION == "B":
        print(f"   • Selected vulnerabilities: {SELECTED_VULNS}")
    elif BATCH_OPTION == "C":
        print(f"   • Selected design: {SELECTED_DESIGN}")
    print("   • Threads: 2 (adjust based on API limits)")

    # Estimate API calls
    designs_count = len(hw_designs) if BATCH_OPTION != "C" else 1
    vulns_count = len(ghost.vulnerabilities) if BATCH_OPTION == "A" else len(SELECTED_VULNS) if BATCH_OPTION == "B" else len(ghost.vulnerabilities)
    total_calls = designs_count * vulns_count
    print(f"   • Estimated API calls: {total_calls}")
# Out:
# 🦠 TASK 2: Batch Trojan Generation
# ==================================================
# 📁 Created 2 baseline designs in ./batch_trojan_designs/
# \n📋 Available Designs:
#    • aes_sbox.v
#    • uart_controller.v
# \n🎯 Vulnerability Types to Generate:
#    • T1: functional-modification vulnerability
#    • T2: information-leakage vulnerability
#    • T3: availability-degradation vulnerability
#    • T4: performance-degradation vulnerability
# \n💼 Batch Processing Options:
# Option A: All vulnerabilities on all designs
# Option B: Specific vulnerabilities only
# Option C: Single design, all vulnerabilities
# \n⚠️  Set RUN_BATCH = True to execute batch job
# 💡 Configuration:
#    • Option: A
#    • Threads: 2 (adjust based on API limits)
#    • Estimated API calls: 8

# %% [markdown]
# ### **Task 3: Trojan Analysis & Comparison**
# Analyze and compare generated Trojans across different vulnerability types and designs.

# %%
#@title Task 3: Trojan Analysis & Comparison
import glob
import re
import csv
from collections import defaultdict

def analyze_trojan_characteristics(output_dir="./batch_trojan_designs"):
    """Comprehensive analysis of generated Trojans"""

    print("🦠 TASK 3: Trojan Analysis & Comparison")
    print("=" * 50)

    if not os.path.exists(output_dir):
        print(f"❌ Output directory {output_dir} not found")
        return

    verilog_files = glob.glob(f"{output_dir}/**/*.v", recursive=True)
    taxonomy_files = glob.glob(f"{output_dir}/**/*_taxonomy.txt", recursive=True)

    print(f"📊 Found {len(verilog_files)} Trojaned designs")
    print(f"📋 Found {len(taxonomy_files)} taxonomy files")

    if not verilog_files:
        print("❌ No Trojaned designs found")
        return

    trojan_stats = defaultdict(list)
    vulnerability_analysis = defaultdict(lambda: defaultdict(list))
    all_rows = []

    for vfile in verilog_files:
        basename = os.path.basename(vfile)
        parts = basename.replace('.v', '').split('_')

        design_name = parts[0] if len(parts) > 0 else 'Unknown'
        vuln_type = next((p for p in parts if p.startswith('H')), 'Unknown')
        model_name = parts[parts.index(vuln_type) + 1] if vuln_type in parts and parts.index(vuln_type) + 1 < len(parts) else 'Unknown'

        with open(vfile, 'r') as f:
            content = f.read()

        lines = len(content.splitlines())
        always_blocks = len(re.findall(r'always\s*@', content))
        if_statements = len(re.findall(r'\bif\s*\(', content))
        registers = len(re.findall(r'\breg\s+', content))
        hardcoded_vals = len(re.findall(r"\d+'[bh][0-9a-fA-F_xXzZ]+", content))
        counters = len(re.findall(r'<=\s*\w+\s*\+\s*1', content))
        comparisons = len(re.findall(r'==\s*\d+', content))

        # Read trigger/payload from corresponding taxonomy file
        tax_path = vfile.replace('.v', '_taxonomy.txt')
        trigger, payload = '', ''
        if os.path.exists(tax_path):
            with open(tax_path, 'r') as f:
                tax = f.read()
            tm = re.search(r'Trigger:\s*(.+?)(?:\n\n|Payload:)', tax, re.DOTALL)
            pm = re.search(r'Payload:\s*(.+?)(?:\n\n|Taxonomy:)', tax, re.DOTALL)
            trigger = tm.group(1).strip().replace('\n', ' ') if tm else ''
            payload = pm.group(1).strip().replace('\n', ' ') if pm else ''

        stats = {
            'file': basename, 'design': design_name, 'vulnerability': vuln_type,
            'model': model_name, 'lines': lines, 'always_blocks': always_blocks,
            'if_statements': if_statements, 'registers': registers,
            'hardcoded_values': hardcoded_vals, 'counters': counters,
            'comparisons': comparisons, 'trigger': trigger, 'payload': payload
        }
        trojan_stats[vuln_type].append(stats)
        vulnerability_analysis[vuln_type][design_name].append(stats)
        all_rows.append(stats)

    # Print summary table
    print("\n" + "=" * 60)
    print("📊 TROJAN CHARACTERISTICS BY VULNERABILITY TYPE")
    print("=" * 60)

    for vuln_type, stats_list in trojan_stats.items():
        print(f"\n🦠 {vuln_type} ({len(stats_list)} samples):")
        avg = lambda key: sum(s[key] for s in stats_list) / len(stats_list)
        print(f"   Lines: {avg('lines'):.1f}  |  if-stmts: {avg('if_statements'):.1f}  |  regs: {avg('registers'):.1f}  |  counters: {avg('counters'):.1f}")
        if stats_list[0]['trigger']:
            print(f"   Sample trigger: {stats_list[0]['trigger'][:120]}")
        if stats_list[0]['payload']:
            print(f"   Sample payload: {stats_list[0]['payload'][:120]}")

    # Export summary.csv
    csv_path = "summary.csv"
    fieldnames = ['file', 'design', 'vulnerability', 'model', 'lines',
                  'always_blocks', 'if_statements', 'registers',
                  'hardcoded_values', 'counters', 'comparisons', 'trigger', 'payload']
    with open(csv_path, 'w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_rows)

    print(f"\n✅ Summary exported to {csv_path} ({len(all_rows)} rows)")

analyze_trojan_characteristics()
# Out:
# 🦠 TASK 3: Trojan Analysis & Comparison
# ==================================================
# 📊 Found 20 Trojaned designs
# 📋 Found 18 taxonomy files
#
# ============================================================
# 📊 TROJAN CHARACTERISTICS BY VULNERABILITY TYPE
# ============================================================
#
# 🦠 Unknown (2 samples):
#    Lines: 23.0  |  if-stmts: 2.0  |  regs: 2.0  |  counters: 0.5
#
# 🦠 HT1 (3 samples):
#    Lines: 45.7  |  if-stmts: 2.3  |  regs: 2.0  |  counters: 0.0
#    Sample trigger: The trojan trigger condition activates when `a` is `0xAA`, `b` is `0x55`, and `op` is `3'b101` occurring more than five
#    Sample payload: When triggered, the payload changes the AND operation to an XOR operation, causing incorrect ALU output for `op == 3'b10
#
# 🦠 HT3 (6 samples):
#    Lines: 42.7  |  if-stmts: 3.7  |  regs: 2.5  |  counters: 1.0
#    Sample trigger: The trigger condition occurs when inputs `a` is `8'b11111111` and `b` is `8'b00000001`. This condition activates the sta
#    Sample payload: When triggered, the payload results in the ALU being non-responsive for up to 256 cycles, before returning to normal ope
#
# 🦠 HT4 (6 samples):
#    Lines: 38.7  |  if-stmts: 1.7  |  regs: 2.3  |  counters: 0.3
#    Sample trigger: The trigger condition for excessive power consumption is implicitly tied to the normal operation of the clock signal, ca
#    Sample payload: The behavior induced by the additional register results in increased power usage during every clock cycle, as it toggles
#
# 🦠 HT2 (3 samples):
#    Lines: 49.0  |  if-stmts: 2.3  |  regs: 3.3  |  counters: 1.0
#    Sample trigger: The trigger condition is when the `op` code is set to `3'b111`, which causes the counter to increment. When the counter
#    Sample payload: When triggered, the top 7 bits of the input 'a' are copied to the `debug_output` wire, allowing an external observer to
#
# ✅ Summary exported to summary.csv (20 rows)

# %% [markdown]
# ### **Task 4: Trojan Validation & Testing**
# Validate that generated Trojans are functionally correct and test their trigger conditions.

# %%
#@title Task 4: Trojan Validation & Testing
import subprocess
import tempfile
import glob
import os
import re

def validate_trojaned_designs(output_dir="./batch_trojan_designs", log_path="validation_log.txt"):
    """Validate syntax and basic functionality of generated Trojaned designs"""

    print("🦠 TASK 4: Trojan Validation & Testing")
    print("=" * 50)

    if not os.path.exists(output_dir):
        print(f"❌ Output directory {output_dir} not found")
        return

    verilog_files = sorted(glob.glob(f"{output_dir}/**/*.v", recursive=True))

    if not verilog_files:
        print("❌ No Trojaned designs found for validation")
        return

    print(f"🔍 Validating {len(verilog_files)} Trojaned designs...")

    validation_results = []
    log_lines = [f"Validation run — {len(verilog_files)} files\n{'='*60}"]

    for vfile in verilog_files:
        basename = os.path.basename(vfile)
        with open(vfile, 'r') as f:
            content = f.read()

        result = {
            'file': basename,
            'syntax_valid': None,
            'has_module': False,
            'has_trojans': False,
            'line_count': len(content.splitlines()),
            'issues': []
        }

        if 'module' in content and 'endmodule' in content:
            result['has_module'] = True
        else:
            result['issues'].append("Missing module/endmodule")

        if 'trojan' in content.lower():
            result['has_trojans'] = True

        suspicious_patterns = [
            r"==\s*\d+'[bh][0-9a-fA-F]+",
            r'<=\s*\w+\s*\+\s*1',
            r'if\s*\([^)]*==\s*\d+',
        ]
        pattern_count = sum(len(re.findall(p, content)) for p in suspicious_patterns)
        if pattern_count > 0:
            result['has_trojans'] = True

        try:
            with tempfile.NamedTemporaryFile(mode='w', suffix='.v', delete=False) as tmp:
                tmp.write(content)
                tmp_name = tmp.name
            rc = subprocess.call(['iverilog', '-t', 'null', tmp_name],
                                 stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
            result['syntax_valid'] = (rc == 0)
            if rc != 0:
                result['issues'].append("Syntax errors detected")
            os.unlink(tmp_name)
        except FileNotFoundError:
            result['syntax_valid'] = None  # iverilog not installed

        validation_results.append(result)

        status = "PASS" if result['has_module'] else "FAIL"
        iverilog_str = "PASS" if result['syntax_valid'] is True else ("FAIL" if result['syntax_valid'] is False else "SKIP")
        log_lines.append(
            f"{basename}: module={status}  iverilog={iverilog_str}  "
            f"trojan_markers={'YES' if result['has_trojans'] else 'NO'}  "
            f"lines={result['line_count']}  issues={result['issues'] or 'none'}"
        )

    # Print summary
    total = len(validation_results)
    valid_mod = sum(1 for r in validation_results if r['has_module'])
    valid_syn = sum(1 for r in validation_results if r['syntax_valid'] is True)
    checked_syn = sum(1 for r in validation_results if r['syntax_valid'] is not None)
    with_trojan = sum(1 for r in validation_results if r['has_trojans'])

    summary = [
        f"\n{'='*60}",
        f"Files validated:        {total}",
        f"Valid module structure: {valid_mod}/{total}",
        f"iverilog syntax pass:   {valid_syn}/{checked_syn} (skipped {total-checked_syn})",
        f"Trojan markers found:   {with_trojan}/{total}",
    ]
    for line in summary:
        print(line)
    log_lines.extend(summary)

    # Write log file
    with open(log_path, 'w') as f:
        f.write('\n'.join(log_lines) + '\n')
    print(f"\n✅ Validation log saved to {log_path}")

validate_trojaned_designs()
# Out:
# 🦠 TASK 4: Trojan Validation & Testing
# ==================================================
# 🔍 Validating 20 Trojaned designs...
#
# ============================================================
# Files validated:        20
# Valid module structure: 20/20
# iverilog syntax pass:   0/0 (skipped 20)
# Trojan markers found:   19/20
#
# ✅ Validation log saved to validation_log.txt

# %% [markdown]
# ## ✅ **TROJAN INSERTION TASKS COMPLETED**
#
# ### 🎯 **Summary of Completed Tasks**
#
# - **Task 1**: ✅ Single Trojan insertion on CPU design
# - **Task 2**: ✅ Batch generation across multiple designs and vulnerabilities
# - **Task 3**: ✅ Comprehensive analysis and comparison of generated Trojans
# - **Task 4**: ✅ Validation and testing of Trojaned designs
#
# ### 📊 **Deliverables Generated**
#
# - 🦠 **Trojaned Hardware Designs**: Modified Verilog files with inserted vulnerabilities
# - 📋 **Taxonomy Documentation**: Detailed trigger/payload/taxonomy descriptions
# - 📈 **Analysis Reports**: Comparative analysis across vulnerability types
# - ✅ **Validation Results**: Syntax and functionality verification
#
# ### 🔬 **Research Applications**
#
# - **Dataset Creation**: Use generated Trojans for detection algorithm training
# - **Benchmark Development**: Create standardized Trojan insertion benchmarks
# - **Defense Testing**: Evaluate security tools against AI-generated attacks
# - **Academic Research**: Publish findings on AI-assisted hardware security
#
# ### ⚠️ **Important Reminders**
#
# - All generated content is for **research and educational purposes only**
# - Never deploy Trojaned designs in production systems
# - Follow institutional research ethics guidelines
# - Use findings to improve hardware security defenses
#
# ### 🚀 **Next Steps**
#
# - Extend to more complex hardware designs (processors, accelerators)
# - Compare results across different AI models and prompting strategies
# - Develop automated detection tools using generated datasets
# - Contribute to hardware security research community

# %% [markdown]
# ## Mini project ideas
# - Prompt red-team / blue-team review
# - Verilog anomaly checker
# - Structured-output validator
# - Taxonomy normalization into JSON

# %% [markdown]
# ## Instructor notes
#
# This notebook is intentionally safe-by-design. It uses the uploaded file as a pipeline-reading and defensive-analysis case study, not as an offensive lab.
